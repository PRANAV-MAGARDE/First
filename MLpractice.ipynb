# %% [markdown]
# <a href="https://colab.research.google.com/github/PRANAV-MAGARDE/First/blob/main/MLpractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LINEAR REGRESSION
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

x = [ [1], [2], [3], [4],[5], [6], [7]]
y = [np.random.rand(), np.random.rand(),np.random.rand(),np.random.rand(),np.random.rand(),np.random.rand(),np.random.rand()]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)
model= LinearRegression().fit(x_train, y_train)

prediction = model.predict([[6]])
coefficient= model.coef_
print(prediction, coefficient)

plt.scatter(x,y, color = 'red')
plt.plot(x, model.predict(x), color ='blue')
plt.show()

#test github upload
# Out:
# [0.73976735] [-0.01784224]
